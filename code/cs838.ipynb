# %%
import py_entitymatching as em
import pandas as pd
import os, sys

# %%
datasets_dir = "/users/rohitsd/Desktop/Datasets"

# %%
path_A = datasets_dir + '/' + 'yelp_data.csv'
path_B = datasets_dir + '/' + 'zomato_data.csv'

# %%
A = em.read_csv_metadata(path_A, key='ID')
B = em.read_csv_metadata(path_B, key='ID')

# %%
ab = em.AttrEquivalenceBlocker()

# %%
C1 = ab.block_tables(A, B, 
                    l_block_attr='zipcode', r_block_attr='zipcode', 
                    l_output_attrs=['name', 'city', 'zipcode', 'review_count', 'latitude', 'longitude', 'rating', 'address', 'zomato_id', 'yelp_id'],
                    r_output_attrs=['name', 'city', 'zipcode','review_count', 'latitude', 'longitude', 'rating', 'address', 'zomato_id', 'yelp_id'],
                    l_output_prefix='l_', r_output_prefix='r_')

# %%
len(C1)
# Out:
# 361156

# %%
C1.to_csv('c.csv')

# %%
C1.head()
# Out:
#    _id   l_ID   r_ID                          l_name     l_city l_zipcode  \
# 0    0     a2  b2383                   Cut and Taste  Las Vegas     89106
# 1    1   a135  b2383                    Guess Outlet  Las Vegas     89106
# 2    2   a155  b2383  Big Mama's Soul Food Rib Shack  Las Vegas     89106
# 3    3   a943  b2383      Mattress Firm Rancho Oakey  Las Vegas     89106
# 4    4  a1154  b2383                Mamma's Boy Cafe  Las Vegas     89106
#
#    l_review_count  l_latitude  l_longitude  l_rating    ...      \
# 0               9   36.192284  -115.159272       5.0    ...
# 1               4   36.162932  -115.158250       1.0    ...
# 2               6   36.177516  -115.173218       2.0    ...
# 3              11   36.173962  -115.160811       5.0    ...
# 4              10   36.183136  -115.160474       3.5    ...
#
#               r_name     r_city r_zipcode r_review_count r_latitude  \
# 0  Broadway Pizzeria  Las Vegas     89106            222   36.16105
# 1  Broadway Pizzeria  Las Vegas     89106            222   36.16105
# 2  Broadway Pizzeria  Las Vegas     89106            222   36.16105
# 3  Broadway Pizzeria  Las Vegas     89106            222   36.16105
# 4  Broadway Pizzeria  Las Vegas     89106            222   36.16105
#
#   r_longitude  r_rating  \
# 0 -115.173014       4.2
# 1 -115.173014       4.2
# 2 -115.173014       4.2
# 3 -115.173014       4.2
# 4 -115.173014       4.2
#
#                                                          r_address  \
# 0  840 South Rancho Drive$*$ Rancho Oakey$*$ Las Vegas$*$ NV 89106
# 1  840 South Rancho Drive$*$ Rancho Oakey$*$ Las Vegas$*$ NV 89106
# 2  840 South Rancho Drive$*$ Rancho Oakey$*$ Las Vegas$*$ NV 89106
# 3  840 South Rancho Drive$*$ Rancho Oakey$*$ Las Vegas$*$ NV 89106
# 4  840 South Rancho Drive$*$ Rancho Oakey$*$ Las Vegas$*$ NV 89106
#
#    r_zomato_id  r_yelp_id
# 0     16977660          0
# 1     16977660          0
# 2     16977660          0
# 3     16977660          0
# 4     16977660          0
#
# [5 rows x 23 columns]

# %%
block_f = em.get_features_for_blocking(A, B)

# %%
block_f
# Out:
#                            feature_name left_attribute right_attribute  \
# 0                        ID_ID_lev_dist             ID              ID
# 1                         ID_ID_lev_sim             ID              ID
# 2                             ID_ID_jar             ID              ID
# 3                             ID_ID_jwn             ID              ID
# 4                             ID_ID_exm             ID              ID
# 5                 ID_ID_jac_qgm_3_qgm_3             ID              ID
# 6             name_name_jac_qgm_3_qgm_3           name            name
# 7         name_name_cos_dlm_dc0_dlm_dc0           name            name
# 8         name_name_jac_dlm_dc0_dlm_dc0           name            name
# 9                         name_name_mel           name            name
# 10                   name_name_lev_dist           name            name
# 11                    name_name_lev_sim           name            name
# 12                        name_name_nmw           name            name
# 13                         name_name_sw           name            name
# 14            city_city_jac_qgm_3_qgm_3           city            city
# 15        city_city_cos_dlm_dc0_dlm_dc0           city            city
# 16        city_city_jac_dlm_dc0_dlm_dc0           city            city
# 17                        city_city_mel           city            city
# 18                   city_city_lev_dist           city            city
# 19                    city_city_lev_sim           city            city
# 20                        city_city_nmw           city            city
# 21                         city_city_sw           city            city
# 22      zipcode_zipcode_jac_qgm_3_qgm_3        zipcode         zipcode
# 23  zipcode_zipcode_cos_dlm_dc0_dlm_dc0        zipcode         zipcode
# 24  zipcode_zipcode_jac_dlm_dc0_dlm_dc0        zipcode         zipcode
# 25                  zipcode_zipcode_mel        zipcode         zipcode
# 26             zipcode_zipcode_lev_dist        zipcode         zipcode
# 27              zipcode_zipcode_lev_sim        zipcode         zipcode
# 28                  zipcode_zipcode_nmw        zipcode         zipcode
# 29                   zipcode_zipcode_sw        zipcode         zipcode
# 30                latitude_latitude_exm       latitude        latitude
# 31                latitude_latitude_anm       latitude        latitude
# 32           latitude_latitude_lev_dist       latitude        latitude
# 33            latitude_latitude_lev_sim       latitude        latitude
# 34              longitude_longitude_exm      longitude       longitude
# 35              longitude_longitude_anm      longitude       longitude
# 36         longitude_longitude_lev_dist      longitude       longitude
# 37          longitude_longitude_lev_sim      longitude       longitude
# 38        review_count_review_count_exm   review_count    review_count
# 39        review_count_review_count_anm   review_count    review_count
# 40   review_count_review_count_lev_dist   review_count    review_count
# 41    review_count_review_count_lev_sim   review_count    review_count
# 42                    rating_rating_exm         rating          rating
# 43                    rating_rating_anm         rating          rating
# 44               rating_rating_lev_dist         rating          rating
# 45                rating_rating_lev_sim         rating          rating
# 46              zomato_id_zomato_id_exm      zomato_id       zomato_id
# 47              zomato_id_zomato_id_anm      zomato_id       zomato_id
# 48         zomato_id_zomato_id_lev_dist      zomato_id       zomato_id
# 49          zomato_id_zomato_id_lev_sim      zomato_id       zomato_id
#
#    left_attr_tokenizer right_attr_tokenizer       simfunction  \
# 0                 None                 None          lev_dist
# 1                 None                 None           lev_sim
# 2                 None                 None              jaro
# 3                 None                 None      jaro_winkler
# 4                 None                 None       exact_match
# 5                qgm_3                qgm_3           jaccard
# 6                qgm_3                qgm_3           jaccard
# 7              dlm_dc0              dlm_dc0            cosine
# 8              dlm_dc0              dlm_dc0           jaccard
# 9                 None                 None       monge_elkan
# 10                None                 None          lev_dist
# 11                None                 None           lev_sim
# 12                None                 None  needleman_wunsch
# 13                None                 None    smith_waterman
# 14               qgm_3                qgm_3           jaccard
# 15             dlm_dc0              dlm_dc0            cosine
# 16             dlm_dc0              dlm_dc0           jaccard
# 17                None                 None       monge_elkan
# 18                None                 None          lev_dist
# 19                None                 None           lev_sim
# 20                None                 None  needleman_wunsch
# 21                None                 None    smith_waterman
# 22               qgm_3                qgm_3           jaccard
# 23             dlm_dc0              dlm_dc0            cosine
# 24             dlm_dc0              dlm_dc0           jaccard
# 25                None                 None       monge_elkan
# 26                None                 None          lev_dist
# 27                None                 None           lev_sim
# 28                None                 None  needleman_wunsch
# 29                None                 None    smith_waterman
# 30                None                 None       exact_match
# 31                None                 None          abs_norm
# 32                None                 None          lev_dist
# 33                None                 None           lev_sim
# 34                None                 None       exact_match
# 35                None                 None          abs_norm
# 36                None                 None          lev_dist
# 37                None                 None           lev_sim
# 38                None                 None       exact_match
# 39                None                 None          abs_norm
# 40                None                 None          lev_dist
# 41                None                 None           lev_sim
# 42                None                 None       exact_match
# 43                None                 None          abs_norm
# 44                None                 None          lev_dist
# 45                None                 None           lev_sim
# 46                None                 None       exact_match
# 47                None                 None          abs_norm
# 48                None                 None          lev_dist
# 49                None                 None           lev_sim
#
#                                                          function  \
# 0                        <function ID_ID_lev_dist at 0x111249e60>
# 1                         <function ID_ID_lev_sim at 0x1112490c8>
# 2                             <function ID_ID_jar at 0x11126a9b0>
# 3                             <function ID_ID_jwn at 0x11126ad70>
# 4                             <function ID_ID_exm at 0x11126a7d0>
# 5                 <function ID_ID_jac_qgm_3_qgm_3 at 0x111259230>
# 6             <function name_name_jac_qgm_3_qgm_3 at 0x10472c140>
# 7         <function name_name_cos_dlm_dc0_dlm_dc0 at 0x11126c0c8>
# 8         <function name_name_jac_dlm_dc0_dlm_dc0 at 0x11126c1b8>
# 9                         <function name_name_mel at 0x11126c2a8>
# 10                   <function name_name_lev_dist at 0x11126c050>
# 11                    <function name_name_lev_sim at 0x11126c140>
# 12                        <function name_name_nmw at 0x11126c230>
# 13                         <function name_name_sw at 0x111266de8>
# 14            <function city_city_jac_qgm_3_qgm_3 at 0x1112662a8>
# 15        <function city_city_cos_dlm_dc0_dlm_dc0 at 0x111266668>
# 16        <function city_city_jac_dlm_dc0_dlm_dc0 at 0x111266a28>
# 17                        <function city_city_mel at 0x1112666e0>
# 18                   <function city_city_lev_dist at 0x1112669b0>
# 19                    <function city_city_lev_sim at 0x111266848>
# 20                        <function city_city_nmw at 0x111266938>
# 21                         <function city_city_sw at 0x111266578>
# 22      <function zipcode_zipcode_jac_qgm_3_qgm_3 at 0x111266230>
# 23  <function zipcode_zipcode_cos_dlm_dc0_dlm_dc0 at 0x111266500>
# 24  <function zipcode_zipcode_jac_dlm_dc0_dlm_dc0 at 0x1112668c0>
# 25                  <function zipcode_zipcode_mel at 0x111266488>
# 26             <function zipcode_zipcode_lev_dist at 0x1112665f0>
# 27              <function zipcode_zipcode_lev_sim at 0x111266398>
# 28                  <function zipcode_zipcode_nmw at 0x10f6ea5f0>
# 29                   <function zipcode_zipcode_sw at 0x10f6ea398>
# 30                <function latitude_latitude_exm at 0x10f6ea2a8>
# 31                <function latitude_latitude_anm at 0x10f6ea6e0>
# 32           <function latitude_latitude_lev_dist at 0x10f6ea668>
# 33            <function latitude_latitude_lev_sim at 0x10f6eaed8>
# 34              <function longitude_longitude_exm at 0x10f6ea758>
# 35              <function longitude_longitude_anm at 0x10f6eaf50>
# 36         <function longitude_longitude_lev_dist at 0x10f6eaaa0>
# 37          <function longitude_longitude_lev_sim at 0x10f6eab90>
# 38        <function review_count_review_count_exm at 0x10f6eac80>
# 39        <function review_count_review_count_anm at 0x10f6ea9b0>
# 40   <function review_count_review_count_lev_dist at 0x10f6eac08>
# 41    <function review_count_review_count_lev_sim at 0x10f6eab18>
# 42                    <function rating_rating_exm at 0x10f6eaa28>
# 43                    <function rating_rating_anm at 0x10f6ea230>
# 44               <function rating_rating_lev_dist at 0x10f6ea578>
# 45                <function rating_rating_lev_sim at 0x10f6ea938>
# 46              <function zomato_id_zomato_id_exm at 0x10f6ea7d0>
# 47              <function zomato_id_zomato_id_anm at 0x1112381b8>
# 48         <function zomato_id_zomato_id_lev_dist at 0x111238aa0>
# 49          <function zomato_id_zomato_id_lev_sim at 0x111238500>
#
#                                                                                         function_source  \
# 0   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 1   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 2   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 3   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 4   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 5   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 6   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 7   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 8   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 9   from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 10  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 11  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 12  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 13  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 14  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 15  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 16  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 17  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 18  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 19  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 20  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 21  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 22  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 23  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 24  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 25  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 26  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 27  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 28  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 29  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 30  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 31  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 32  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 33  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 34  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 35  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 36  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 37  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 38  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 39  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 40  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 41  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 42  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 43  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 44  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 45  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 46  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 47  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 48  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
# 49  from py_entitymatching.feature.simfunctions import *\nfrom py_entitymatching.feature.tokenizers ...
#
#    is_auto_generated
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# 9               True
# 10              True
# 11              True
# 12              True
# 13              True
# 14              True
# 15              True
# 16              True
# 17              True
# 18              True
# 19              True
# 20              True
# 21              True
# 22              True
# 23              True
# 24              True
# 25              True
# 26              True
# 27              True
# 28              True
# 29              True
# 30              True
# 31              True
# 32              True
# 33              True
# 34              True
# 35              True
# 36              True
# 37              True
# 38              True
# 39              True
# 40              True
# 41              True
# 42              True
# 43              True
# 44              True
# 45              True
# 46              True
# 47              True
# 48              True
# 49              True

# %%
rb = em.RuleBasedBlocker()
rb.add_rule(['name_name_lev_sim(ltuple, rtuple) < 0.4'], block_f)
# Out:
# '_rule_0'

# %%
D = rb.block_candset(C1, show_progress=False)

# %%
D.to_csv('D.csv')

# %%
len(D)
# Out:
# 2472

# %%
S = em.sample_table(D, 600)

# %%
S
# Out:
#            _id     l_ID   r_ID                          l_name        l_city  \
# 541        541   a41175  b2373               The Chicken Shack     Henderson
# 1157      1157   a68958   b571                  Ray's Pizza II       Phoenix
# 1204      1204  a120029   b571              Sauce Pizza & Wine       Phoenix
# 2028      2028  a106870  b3561         Trattoria Roman Gardens     Cleveland
# 2059      2059  a117289  b3515                      L'Albatros     Cleveland
# 3161      3161  a115302   b304                Teriyaki Madness     Charlotte
# 4051      4051   a40842   b378                     Jet's Pizza  Huntersville
# 360888  EH10 5DP               8   55.933825    -3.210662       4.0
# 360964   H9H 3C4               4   45.456468   -73.862532       4.0
# 360983   EH3 5AN              26   55.957573    -3.207439       4.0
# 360991   EH6 8PD              14   55.965491    -3.175873       4.0
# 361005   EH3 9AL              25   55.945930    -3.204728       4.0
# 361017   M6J 1W3             432   43.650978   -79.413280       4.0
# 361044   EH1 2EL               8   55.947088    -3.202143       3.0
# 361090   EH2 3LJ              42   55.953873    -3.204167       4.5
# 361091   M4R 1A9              67   43.704803   -79.405689       3.5
# 361093   H2T 1P7               8   45.523224   -73.583323       4.0
# 361114   EH3 9BE              23   55.946390    -3.205829       4.0
# 361133   L5G 2T3              62   43.552529   -79.585519       4.0
# 361139   EH6 6EW              66   55.975966    -3.173519       4.0
#
#           ...                           r_name      r_city r_zipcode  \
# 541       ...                  The Cracked Egg   Las Vegas     89074
# 1157      ...               Sauce Pizza & Wine     Phoenix     85085
# 1204      ...               Sauce Pizza & Wine     Phoenix     85085
# 2028      ...            Trattoria on the Hill   Cleveland     44106
# 2059      ...                       L'Albatros   Cleveland     44106
# 3161      ...                   Toyama Express   Charlotte     28262
# 4051      ...                     Tony's Pizza   Charlotte     28078
# 4129      ...                     Tony's Pizza   Charlotte     28078
# 4141      ...                     Tony's Pizza   Charlotte     28078
# 5067      ...      La Unica Mexican Restaurant   Charlotte     28078
# 5664      ...                        Bagel Bin   Charlotte     28078
# 6882      ...             Yen Sushi & Sake Bar     Phoenix     85308
# 7186      ...             Yen Sushi & Sake Bar     Phoenix     85308
# 7476      ...             Yen Sushi & Sake Bar     Phoenix     85308
# 8446      ...       Firebirds Wood Fired Grill   Charlotte     28277
# 8704      ...       Firebirds Wood Fired Grill   Charlotte     28277
# 12099     ...                      Bad Daddy's   Charlotte     28277
# 13674     ...                       Thai Taste   Charlotte     28203
# 13690     ...                 Mac's Speed Shop   Charlotte     28203
# 14185     ...            Luna's Living Kitchen   Charlotte     28203
# 15031     ...                         300 East   Charlotte     28203
# 16143     ...            Sullivan's Steakhouse   Charlotte     28203
# 16308     ...             Price's Chicken Coop   Charlotte     28203
# 17310     ...                 Mac's Speed Shop   Charlotte     28203
# 17341     ...                         300 East   Charlotte     28203
# 19532     ...                   Nora's Cuisine   Las Vegas     89103
# 19668     ...                   Nora's Cuisine   Las Vegas     89103
# 20646     ...                  In-N-Out Burger   Las Vegas     89103
# 20869     ...            Carnival World Buffet   Las Vegas     89103
# 22096     ...                   Nora's Cuisine   Las Vegas     89103
# ...       ...                              ...         ...       ...
# 359921    ...               Tom's Dairy Freeze         GTA   M8Y 1K5
# 359939    ...              Mother India's Cafe   Edinburgh   EH1 1LT
# 359951    ...                 ND Sushi & Grill     Toronto   M5T 1L1
# 359975    ...                 ND Sushi & Grill     Toronto   M5T 1L1
# 360150    ...        Green Forest Churrascaria  Pittsburgh     15235
# 360293    ...                     Maison Bleue   Edinburgh   EH1 2JW
# 360410    ...                        Bar Raval     Toronto   M6G 1A4
# 360519    ...                        Gusto 101     Toronto   M5V 2N3
# 360529    ...                           Voujon   Edinburgh   EH9 1QW
# 360557    ...                        El Cartel   Edinburgh   EH2 1EN
# 360649    ...                      Han Ba Tang         GTA   M2N 5N2
# 360694    ...      Number One - Balmoral Hotel   Edinburgh   EH2 2EQ
# 360784    ...                   Ott's Drive In   Champaign     61866
# 360818    ...                   Hard Rock Cafe   Edinburgh   EH2 2PF
# 360851    ...         Buk Chang Dong Soon Tofu     Toronto   M6G 1L3
# 360856    ...                        La Piazza   Edinburgh   EH2 4SD
# 360871    ...                    Foxley Bistro     Toronto   M6J 2Z8
# 360888    ...                      Bia Bistrot   Edinburgh  EH10 5DP
# 360964    ...                    Bistro Merlot    Montreal   H9H 3C4
# 360983    ...                     Bell's Diner   Edinburgh   EH3 5AN
# 360991    ...                          Origano   Edinburgh   EH6 8PD
# 361005    ...                          Bentoya   Edinburgh   EH3 9AL
# 361017    ...                   The Black Hoof     Toronto   M6J 1W3
# 361044    ...                   Castle Terrace   Edinburgh   EH1 2EL
# 361090    ...        Restaurant Mark Greenaway   Edinburgh   EH2 3LJ
# 361091    ...                     Burger Shack     Toronto   M4R 1A9
# 361093    ...                           Pintxo    Montreal   H2T 1P7
# 361114    ...                Bread Meats Bread   Edinburgh   EH3 9BE
# 361133    ...                     Burrito Boyz         GTA   L5G 2T3
# 361139    ...                Roseleaf Bar Cafe   Edinburgh   EH6 6EW
#
#        r_review_count r_latitude r_longitude  r_rating  \
# 541               318  36.027749 -115.085723       4.2
# 1157              215  33.713052 -112.111734       4.0
# 1204              215  33.713052 -112.111734       4.0
# 2028              795  41.508837  -81.597650       4.2
# 2059              884  41.511500  -81.605604       4.5
# 3161              560  35.337772  -80.756986       4.7
# 4051              237  35.357386  -80.868146       4.2
# 4129              237  35.357386  -80.868146       4.2
# 4141              237  35.357386  -80.868146       4.2
# 5067              471  35.436652  -80.870662       4.4
# 5664              229  35.442068  -80.861476       4.2
# 6882              238  33.639965 -112.151650       4.3
# 7186              238  33.639965 -112.151650       4.3
# 7476              238  33.639965 -112.151650       4.3
# 8446             1271  35.062055  -80.815844       4.3
# 8704             1271  35.062055  -80.815844       4.3
# 12099             865  35.053778  -80.846781       4.5
# 13674             459  35.210508  -80.856277       4.1
# 13690            1673  35.202942  -80.864358       4.3
# 14185             244  35.208548  -80.861530       4.1
# 15031             617  35.210862  -80.856527       4.3
# 16143             486  35.210526  -80.859246       4.1
# 16308            1093  35.214563  -80.857329       4.5
# 17310            1673  35.202942  -80.864358       4.3
# 17341             617  35.210862  -80.856527       4.3
# 19532             548  36.114777 -115.223348       4.2
# 19668             548  36.114777 -115.223348       4.2
# 20646            1071  36.101009 -115.182811       4.8
# 20869             382  36.115700 -115.187000       4.1
# 22096             548  36.114777 -115.223348       4.2
# ...               ...        ...         ...       ...
# 359921            205  43.627750  -79.496658       4.4
# 359939            279  55.948003   -3.186250       4.4
# 359951            382  43.656236  -79.392411       4.5
# 359975            382  43.656236  -79.392411       4.5
# 17310                             2511 South Boulevard$*$ Charlotte$*$ NC 28203
# 17341                               300 East Boulevard$*$ Charlotte$*$ NC 28203
# 19532                             6020 W Flamingo Road$*$ Las Vegas$*$ NV 89103
# 19668                             6020 W Flamingo Road$*$ Las Vegas$*$ NV 89103
# 20646                           4888 Dean Martin Drive$*$ Las Vegas$*$ NV 89103
# 20869                               3700 W Flamingo Rd$*$ Las Vegas$*$ NV 89103
# 22096                             6020 W Flamingo Road$*$ Las Vegas$*$ NV 89103
# ...                                                                         ...
# 359921                                   630 The Queensway$*$ Etobicoke M8Y 1K5
# 359939                    3-5 Infirmary Street$*$ Old Town$*$ Edinburgh EH1 1LT
# 359951                                      3 Baldwin Street$*$ Toronto M5T 1L1
# 359975                                      3 Baldwin Street$*$ Toronto M5T 1L1
# 360150                                655 Rodi Rd$*$ Penn Hills Twp$*$ PA 15235
# 360293                          36-38 West Bow$*$ Old Town$*$ Edinburgh EH1 2JW
# 360410                              505 College Street$*$ Toronto$*$ ON M6G 1A4
# 360519                             101 Portland Street$*$ Toronto$*$ ON M5V 2N3
# 360529                     107 Newington Road$*$ Newington$*$ Edinburgh EH9 1QW
# 360557                       64 Thistle Street$*$ New Town$*$ Edinburgh EH2 1EN
# 360649                            4862 Yonge Street$*$ North York$*$ ON M2N 5N2
# 360694  The Balmoral Hotel$*$ 1 Princes Street$*$ New Town$*$ Edinburgh EH2 2EQ
# 360784                                400 N Century Blvd$*$ Rantoul$*$ IL 61866
# 360818                        20 George Street$*$ New Town$*$ Edinburgh EH2 2PF
# 360851                                 691 Bloor Street West$*$ Toronto M6G 1L3
# 360856                   97-99 Shandwick Place$*$ West End$*$ Edinburgh EH2 4SD
# 360871                            207 Ossington Avenue$*$ Toronto$*$ ON M6J 2Z8
# 360888                    19 Colinton Road$*$ Morningside$*$ Edinburgh EH10 5DP
# 360964                        3541 Blvd Saint-Charles$*$ Kirkland$*$ QC H9H 3C4
# 360983                 7 St. Stephen Street$*$ Stockbridge$*$ Edinburgh EH3 5AN
# 360991                             236 Leith Walk$*$ Leith$*$ Edinburgh EH6 8PD
# 361005                         15 Bread Street$*$ Old Town$*$ Edinburgh EH3 9AL
# 361017                          928 Dundas Street West$*$ Toronto$*$ ON M6J 1W3
# 361044                    33-35 Castle Terrace$*$ Old Town$*$ Edinburgh EH1 2EL
# 361090                  69 North Castle Street$*$ New Town$*$ Edinburgh EH2 3LJ
# 361091                        233 Eglinton Avenue West$*$ Toronto$*$ ON M4R 1A9
# 361093                     330 Avenue du Mont-Royal E$*$ Montreal$*$ QC H2T 1P7
# 361114                      90-92 Lothian Road$*$ Old Town$*$ Edinburgh EH3 9BE
# 361133                            9 Stavebank Road$*$ Mississauga$*$ ON L5G 2T3
# 361139                       23-24 Sandport Place$*$ Leith$*$ Edinburgh EH6 6EW
#
#         r_zomato_id  r_yelp_id
# 541        16981241          0
# 1157       17030169          0
# 1204       17030169          0
# 2028       16963129          0
# 2059       16964270          0
# 3161       17148399          0
# 4051       17148387          0
# 4129    Huntersville     28078               6   35.436211   -80.865706
# 4141    Huntersville     28078               4   35.443106   -80.859585
# 4185    Huntersville     28078              21   35.384346   -80.786208
# ...              ...       ...             ...         ...          ...
# 361049     Edinburgh   EH1 1AD              53   55.948309    -3.192178
# 361050     Edinburgh   EH8 8AE             121   55.949398    -3.182719
# 361065     Edinburgh   EH3 9AS              64   55.946436    -3.203785
# 361067     Edinburgh   EH8 9BH              59   55.946962    -3.185930
# 361069       Toronto   M4W 1S9             258   43.677122   -79.389210
# 361071      Oakville   L6M 2A3              70   43.444997   -79.727668
# 361075   Scarborough   M1B 1G8              91   43.798467   -79.148217
# 361082     Edinburgh   EH2 3BG              24   55.953090    -3.203472
# 361085     Edinburgh  EH11 2AB              28   55.943534    -3.219324
# 361090     Edinburgh   EH2 3LJ              42   55.953873    -3.204167
# 361091       Toronto   M4R 1A9              67   43.704803   -79.405689
# 361093       Montral   H2T 1P7               8   45.523224   -73.583323
# 361094     Edinburgh   EH2 1EA              27   55.954038    -3.200225
# 361095     Edinburgh   EH1 3PY              15   55.956761    -3.192822
# 361096     Edinburgh   EH2 3DN              25   55.952195    -3.203124
# 361101        Presto     15142              54   40.372716   -80.119530
# 361105       Montral   H2Y 2N7             150   45.502689   -73.558162
# 361108       Montral   H2Y 2A7             643   45.501197   -73.556338
# 361114     Edinburgh   EH3 9BE              23   55.946390    -3.205829
# 361121     Edinburgh   EH2 1DY              10   55.953921    -3.199709
# 361125     Edinburgh   EH2 1DY              56   55.954005    -3.199729
# 361133   Mississauga   L5G 2T3              62   43.552529   -79.585519
# 361138       Toronto   M4M 1L7             166   43.663335   -79.330419
# 361139     Edinburgh   EH6 6EW              66   55.975966    -3.173519
# 361141       Toronto   M2P 2C6             221   43.746961   -79.407911
# 361142    West Akron     44313              75   41.108641   -81.569681
# 361146       Toronto   M5V 1R1             286   43.647491   -79.391954
# 361147     Edinburgh   EH6 4NQ              22   55.980170    -3.197695
# 361148       Toronto   M6E 1C4              63   43.676866   -79.449298
# 361150     Edinburgh   EH1 1EE             161   55.947960    -3.192143
#
#         l_rating    ...                                        r_name  \
# 30           4.0    ...                             Broadway Pizzeria
# 480          3.5    ...                               The Cracked Egg
# 541          4.0    ...                               The Cracked Egg
# 630          3.0    ...                               The Cracked Egg
# 1157         3.0    ...                            Sauce Pizza & Wine
# 1204         3.5    ...                            Sauce Pizza & Wine
# 1327         4.0    ...                    Firebirds Wood Fired Grill
# 1464         3.5    ...                       Bonfyre American Grille
# 1486         2.5    ...                       Bonfyre American Grille
# 1497         4.0    ...                       Bonfyre American Grille
# 1619         4.0    ...                         Presti's Bakery & Caf
# 1937         4.0    ...                         Presti's Bakery & Caf
# 2028         3.5    ...                         Trattoria on the Hill
# 2039         4.5    ...                         Presti's Bakery & Caf
# 2059         4.5    ...                                    L'Albatros
# 2377         4.5    ...                                  KoMex Fusion
# 2936         4.0    ...            The Flying Saucer Draught Emporium
# 2991         3.0    ...                                Toyama Express
# 3019         3.0    ...                                Toyama Express
# 3161         3.5    ...                                Toyama Express
# 3277         4.0    ...                                  Tony's Pizza
# 3528         3.0    ...                                     Bagel Bin
# 3541         4.0    ...                                  Tony's Pizza
# 3556         4.5    ...                                   Killingtons
# 3865         4.0    ...                                  Tony's Pizza
# 4041         4.0    ...                   La Unica Mexican Restaurant
# 4051         4.0    ...                                  Tony's Pizza
# 4129         2.5    ...                                  Tony's Pizza
# 4141         2.5    ...                                  Tony's Pizza
# 4185         3.0    ...                   La Unica Mexican Restaurant
# ...          ...    ...                                           ...
# 361049       4.5    ...                                        Ondine
# 361050       4.0    ...                               The Holyrood 9A
# 361065       4.5    ...                                        Kanpai
# 361067       4.0    ...                                   Kebab Mahal
# 361069       4.5    ...                                   Black Camel
# 361071       4.5    ...               Monastery Bakery & Delicatessen
# 361075       4.0    ...                              Lamanna's Bakery
# 361082       4.0    ...                                   Time 4 Thai
# 361085       4.0    ...                                   First Coast
# 361090       4.5    ...                     Restaurant Mark Greenaway
# 361091       3.5    ...                                  Burger Shack
# 361093       4.0    ...                                        Pintxo
# 361094       4.5    ...                                Cafe St Honore
# 361095       4.5    ...                   The Magnum Bar & Restaurant
# 361096       4.0    ...                                    Chaophraya
# 361101       4.5    ...                              Two Brothers BBQ
# 361105       4.5    ...                                     L'Orignal
# 361108       4.5    ...                            Olive Et Gourmando
# 361114       4.0    ...                             Bread Meats Bread
# 361121       4.5    ...                                The Bon Vivant
# 361125       4.0    ...                                The Bon Vivant
# 361133       4.0    ...                                  Burrito Boyz
# 361138       4.0    ...      Gio Rana's Really Really Nice Restaurant
# 361139       4.0    ...                             Roseleaf Bar Cafe
# 361141       4.0    ...                            Auberge du Pommier
# 361142       4.5    ...                                     Swenson's
# 361146       4.5    ...                                    Ravi Soups
# 361147       3.5    ...                                    Porto & Fi
# 361148       3.5    ...                           Frank's Pizza House
# 361150       4.0    ...                                  The Outsider
#
#             r_city r_zipcode r_review_count r_latitude r_longitude  r_rating  \
# 30       Las Vegas     89106            222  36.161050 -115.173014       4.2
# 480      Las Vegas     89074            318  36.027749 -115.085723       4.2
# 541      Las Vegas     89074            318  36.027749 -115.085723       4.2
# 630      Las Vegas     89074            318  36.027749 -115.085723       4.2
# 1157       Phoenix     85085            215  33.713052 -112.111734       4.0
# 1204       Phoenix     85085            215  33.713052 -112.111734       4.0
# 1327     Charlotte     28216            423  35.349937  -80.850339       4.2
# 1464       Madison     53713            575  43.034786  -89.421180       4.2
# 1486       Madison     53713            575  43.034786  -89.421180       4.2
# 1497       Madison     53713            575  43.034786  -89.421180       4.2
# 1619     Cleveland     44106            544  41.508837  -81.598206       4.4
# 1937     Cleveland     44106            544  41.508837  -81.598206       4.4
# 2028     Cleveland     44106            795  41.508837  -81.597650       4.2
# 2039     Cleveland     44106            544  41.508837  -81.598206       4.4
# 2059     Cleveland     44106            884  41.511500  -81.605604       4.5
# 2377     Las Vegas     89107            195  36.179453 -115.206350       4.3
# 2936     Charlotte     28262            446  35.316954  -80.738968       4.1
#                                                                                    r_address  \
# 30                           840 South Rancho Drive$*$ Rancho Oakey$*$ Las Vegas$*$ NV 89106
# 480                                1000 N Green Valley Parkway #480$*$ Henderson$*$ NV 89074
# 541                                1000 N Green Valley Parkway #480$*$ Henderson$*$ NV 89074
# 630                                1000 N Green Valley Parkway #480$*$ Henderson$*$ NV 89074
# 1157                                           2470 W Happy Valley Rd$*$ Phoenix$*$ AZ 85085
# 1204                                           2470 W Happy Valley Rd$*$ Phoenix$*$ AZ 85085
# 1327                                      6801 Northlake Mall Drive$*$ Charlotte$*$ NC 28216
# 1464                                       2601 West Beltline Highway$*$ Madison$*$ WI 53713
# 1486                                       2601 West Beltline Highway$*$ Madison$*$ WI 53713
# 1497                                       2601 West Beltline Highway$*$ Madison$*$ WI 53713
# 1619                                              12101 Mayfield Rd$*$ Cleveland$*$ OH 44106
# 1937                                              12101 Mayfield Rd$*$ Cleveland$*$ OH 44106
# 2028                                              12207 Mayfield Rd$*$ Cleveland$*$ OH 44106
# 2039                                              12101 Mayfield Rd$*$ Cleveland$*$ OH 44106
# 2059                                            11401 Bellflower Rd$*$ Cleveland$*$ OH 44106
# 2377                                       633 N Decatur Blvd Ste H$*$ Las Vegas$*$ NV 89107
# 2936    Terraces At University Place$*$ 9605 N Tryon Street Suite A$*$ Charlotte$*$ NC 28262
# 2991                                            2130 E Arbors Drive$*$ Charlotte$*$ NC 28262
# 3019                                            2130 E Arbors Drive$*$ Charlotte$*$ NC 28262
# 3161                                            2130 E Arbors Drive$*$ Charlotte$*$ NC 28262
# 3277                             9548 Mount Holly-Huntersville Road$*$ Charlotte$*$ NC 28078
# 3528                                    Northcross$*$ 9815 Sam Furr Road Suite I$*$ NC 28078
# 3541                             9548 Mount Holly-Huntersville Road$*$ Charlotte$*$ NC 28078
# 3556                                       10010 Rose Commons Dr$*$ Huntersville$*$ NC 28078
# 3865                             9548 Mount Holly-Huntersville Road$*$ Charlotte$*$ NC 28078
# 4041                         16203 Northcross Drive$*$ Huntersville$*$ Charlotte$*$ NC 28078
# 4051                             9548 Mount Holly-Huntersville Road$*$ Charlotte$*$ NC 28078
# 4129                             9548 Mount Holly-Huntersville Road$*$ Charlotte$*$ NC 28078
# 4141                             9548 Mount Holly-Huntersville Road$*$ Charlotte$*$ NC 28078
# 4185                         16203 Northcross Drive$*$ Huntersville$*$ Charlotte$*$ NC 28078
# ...                                                                                      ...
# 361049                                   2 George IV Bridge$*$ Old Town$*$ Edinburgh EH1 1AD
# 361050                                     9A Holyrood Road$*$ Old Town$*$ Edinburgh EH8 8AE
# 361065                                 8-10 Grindlay Street$*$ Old Town$*$ Edinburgh EH3 9AS
# 361067                                    7 Nicolson Square$*$ Old Town$*$ Edinburgh EH8 9BH
# 361069                                              4 Crescent Road$*$ Toronto$*$ ON M4W 1S9
# 361071                                        1133 Monastery Drive$*$ Oakville$*$ ON L6M 2A3
# 361075                                             6758 Kingston Road$*$ Scarborough M1B 1G8
# 361082                               45 North Castle Street$*$ New Town$*$ Edinburgh EH2 3BG
# 361085                                      97-101 Dalry Road$*$ Dalry$*$ Edinburgh EH11 2AB
# 361090                               69 North Castle Street$*$ New Town$*$ Edinburgh EH2 3LJ
# 361091                                     233 Eglinton Avenue West$*$ Toronto$*$ ON M4R 1A9
# 361093                                  330 Avenue du Mont-Royal E$*$ Montreal$*$ QC H2T 1P7
# 361094                             34 Thistle Street$*$ North West Lane$*$ Edinburgh EH2 1EA
# 361095                                      1 Albany Street$*$ New Town$*$ Edinburgh EH1 3PY
# 361096                        4th Floor$*$ 33 Castle Street$*$ New Town$*$ Edinburgh EH2 3DN
# 361101                                               5228 Thoms Run Rd$*$ Presto$*$ PA 15142
# 361105                                        479 Rue Saint Alexis$*$ Montreal$*$ QC H2Y 2N7
# 361108                                           351 Rue St-Paul O$*$ Montreal$*$ QC H2Y 2A7
# 361114                                   90-92 Lothian Road$*$ Old Town$*$ Edinburgh EH3 9BE
# 361121                                 51-55 Thistle Street$*$ New Town$*$ Edinburgh EH2 1DY
# 361125                                 51-55 Thistle Street$*$ New Town$*$ Edinburgh EH2 1DY
# 361133                                         9 Stavebank Road$*$ Mississauga$*$ ON L5G 2T3
# 361138                                       1220 Queen Street East$*$ Toronto$*$ ON M4M 1L7
# 361139                                    23-24 Sandport Place$*$ Leith$*$ Edinburgh EH6 6EW
# 361141                                         4150 Yonge Street$*$ North York$*$ ON M2P 2C6
# 361142                                                 40 S Hawkins Ave$*$ Akron$*$ OH 44313
# 361146                                     322 Adelaide Street West$*$ Toronto$*$ ON M5V 1R1
# 361147                                 47 Newhaven Main Street$*$ Leith$*$ Edinburgh EH6 4NQ
# 361148                                   1352 St. Clair Avenue West$*$ Toronto$*$ ON M6E 1C4
# 361150                             15 - 16 George IV Bridge$*$ Old Town$*$ Edinburgh EH1 1EE
#
#         r_zomato_id  r_yelp_id
# 30         16977660          0
# 480        16981241          0
# 541        16981241          0
# 630        16981241          0
# 1157       17030169          0
# 1204       17030169          0
# 1327       17147235          0
# 1464       17503464          0
# 1486       17503464          0
# 1497       17503464          0
# 1619       16962390          0
# 1937       16962390          0
# 2028       16963129          0
# 2039       16962390          0
# 2059       16964270          0
# 2377       16982239          0
# 2936       17147264          0
# 2991       17148399          0
# 3019       17148399          0
# 3161       17148399          0
# 3277       17148387          0
# 3528       17146715          0
# 3541       17148387          0
# 3556       17148631          0
# 3865       17148387          0
# 4041       17149565          0
# 4051       17148387          0
# 4129       17148387          0
# 4141       17148387          0
# 4185       17149565          0
# ...             ...        ...
# 361049      7600218          0
# 361050      7600238          0
# 361065      7600211          0
# 361067      7601739          0
# 361069      8910322          0
# 361071     17735840          0
# 361075      8900844          0
# 361082      7601034          0
# 361085      7600203          0
# 361090      7600422          0
# 361091      8908687          0
# 361093     16635563          0
# 361094      7601175          0
# 361095      7600589          0
# 361096      7601102          0
# 361101     17037951          0
# 361105     16636716          0
# 361108     16635422          0
# 361114      7602603          0
# 361121      7600566          0
# 361125      7600566          0
# 361133     16541911          0
# 361138      8906219          0
# 361139      7601577          0
# 361141      8910545          0
# 361142     16962981          0
# 361146      8905251          0
# 361147      7601388          0
# 361148      8908418          0
# 361150      7601774          0
#
# [2472 rows x 23 columns]

# %%
S.to_csv('S.csv')

# %%
#G = em.label_table(S, 'label')

# %%
#G.head()

# %%
len(S)
# Out:
# 600

# %%
path_labeled_data = datasets_dir + '/' + 'labeled.csv'

# %%
G = em.read_csv_metadata(path_labeled_data, key='_id', 
                         fk_ltable='l_ID', fk_rtable='r_ID',
                         ltable=A, rtable=B)

# %%
G.head()
# Out:
#    Unnamed: 0   _id     l_ID   r_ID                          l_name  \
# 0        1327  1327   a88298   b362      Firebirds Wood Fired Grill
# 1        2028  2028  a106870  b3561         Trattoria Roman Gardens
# 2        2991  2991   a77320   b304                 Hibachi Express
# 3        3161  3161  a115302   b304                Teriyaki Madness
# 4        5337  5337  a104781   b326  Huntersville Family Restaurant
#
#          l_city l_zipcode  l_review_count  l_latitude  l_longitude  ...    \
# 0     Charlotte     28216             110   35.352549   -80.851181  ...
# 1     Cleveland     44106             137   41.508872   -81.597717  ...
# 2     Charlotte     28262               5   35.297087   -80.755382  ...
# 3     Charlotte     28262              16   35.340273   -80.764928  ...
# 4  Huntersville     28078              28   35.414040   -80.852580  ...
#
#       r_city r_zipcode  r_review_count r_latitude r_longitude r_rating  \
# 0  Charlotte     28216             423  35.349937  -80.850339      4.2
# 1  Cleveland     44106             795  41.508837  -81.597650      4.2
# 2  Charlotte     28262             560  35.337772  -80.756986      4.7
# 3  Charlotte     28262             560  35.337772  -80.756986      4.7
# 4  Charlotte     28078             471  35.436652  -80.870662      4.4
#
#                                                          r_address  \
# 0               6801 Northlake Mall Drive$*$ Charlotte$*$ NC 28216
# 1                       12207 Mayfield Rd$*$ Cleveland$*$ OH 44106
# 2                     2130 E Arbors Drive$*$ Charlotte$*$ NC 28262
# 3                     2130 E Arbors Drive$*$ Charlotte$*$ NC 28262
# 4  16203 Northcross Drive$*$ Huntersville$*$ Charlotte$*$ NC 28078
#
#    r_zomato_id  r_yelp_id  label
# 0     17147235          0      1
# 1     16963129          0      1
# 2     17148399          0      0
# 3     17148399          0      0
# 4     17149565          0      0
#
# [5 rows x 25 columns]

# %%
train_test = em.split_train_test(G, train_proportion=0.5)
I = train_test['train']
J = train_test['test']

# %%
I.to_csv('I.csv')
J.to_csv('J.csv')

# %%
match_f = em.get_features_for_matching(A, B)

# %%
match_f.feature_name
# Out:
# 0                          ID_ID_lev_dist
# 1                           ID_ID_lev_sim
# 2                               ID_ID_jar
# 3                               ID_ID_jwn
# 4                               ID_ID_exm
# 5                   ID_ID_jac_qgm_3_qgm_3
# 6               name_name_jac_qgm_3_qgm_3
# 7           name_name_cos_dlm_dc0_dlm_dc0
# 8           name_name_jac_dlm_dc0_dlm_dc0
# 9                           name_name_mel
# 10                     name_name_lev_dist
# 11                      name_name_lev_sim
# 12                          name_name_nmw
# 13                           name_name_sw
# 14              city_city_jac_qgm_3_qgm_3
# 15          city_city_cos_dlm_dc0_dlm_dc0
# 16          city_city_jac_dlm_dc0_dlm_dc0
# 17                          city_city_mel
# 18                     city_city_lev_dist
# 19                      city_city_lev_sim
# 20                          city_city_nmw
# 21                           city_city_sw
# 22        zipcode_zipcode_jac_qgm_3_qgm_3
# 23    zipcode_zipcode_cos_dlm_dc0_dlm_dc0
# 24    zipcode_zipcode_jac_dlm_dc0_dlm_dc0
# 25                    zipcode_zipcode_mel
# 26               zipcode_zipcode_lev_dist
# 27                zipcode_zipcode_lev_sim
# 28                    zipcode_zipcode_nmw
# 29                     zipcode_zipcode_sw
# 30                  latitude_latitude_exm
# 31                  latitude_latitude_anm
# 32             latitude_latitude_lev_dist
# 33              latitude_latitude_lev_sim
# 34                longitude_longitude_exm
# 35                longitude_longitude_anm
# 36           longitude_longitude_lev_dist
# 37            longitude_longitude_lev_sim
# 38          review_count_review_count_exm
# 39          review_count_review_count_anm
# 40     review_count_review_count_lev_dist
# 41      review_count_review_count_lev_sim
# 42                      rating_rating_exm
# 43                      rating_rating_anm
# 44                 rating_rating_lev_dist
# 45                  rating_rating_lev_sim
# 46                zomato_id_zomato_id_exm
# 47                zomato_id_zomato_id_anm
# 48           zomato_id_zomato_id_lev_dist
# 49            zomato_id_zomato_id_lev_sim
# Name: feature_name, dtype: object

# %%
H = em.extract_feature_vecs(I, 
                            feature_table=match_f, 
                            attrs_after='label',
                            show_progress=False)

# %%
I.head()
# Out:
#      Unnamed: 0     _id    l_ID   r_ID                  l_name     l_city  \
# 344      238081  238081   a1848  b1698       Za's Italian Cafe  Champaign
# 230      145504  145504  a40525  b2396     Battle Of The Dance  Las Vegas
# 167       96455   96455  a14256  b2345              Sushi Loca  Las Vegas
# 282      193423  193423  a85829  b2304          Art of Shaving  Las Vegas
# 217      134243  134243  a11165  b2313  Chipotle Mexican Grill  Las Vegas
#
#     l_zipcode  l_review_count  l_latitude  l_longitude  ...       r_city  \
# 344     61820              29   40.139925   -88.245853  ...    Champaign
# 230     89109               3   36.104494  -115.167285  ...    Las Vegas
# 167     89149             340   36.272533  -115.266725  ...    Las Vegas
# 282     89109               9   36.124340  -115.167767  ...    Las Vegas
# 217     89109              95   36.120095  -115.171769  ...    Las Vegas
#
#     r_zipcode  r_review_count r_latitude r_longitude r_rating  \
# 344     61820              51  40.116800  -88.242700      3.6
# 230     89109             587  36.114988 -115.168072      4.1
# 167     89149             558  36.272400 -115.265500      4.3
# 282     89109             631  36.110770 -115.172820      4.7
# 217     89109            1410  36.116111 -115.174400      4.5
#
#                                                                                     r_address  \
# 344                                                  115 N Walnut St$*$ Champaign$*$ IL 61820
# 230                                      4041 Linq Lane$*$ The Strip$*$ Las Vegas$*$ NV 89109
# 167                                        6181 Centennial Center Bl$*$ Las Vegas$*$ NV 89149
# 282  Planet Hollywood$*$ 3667 South Las Vegas Boulevard$*$ The Strip$*$ Las Vegas$*$ NV 89109
# 217                                       3570 Las Vegas Boulevard S$*$ Las Vegas$*$ NV 89109
#
#      r_zomato_id  r_yelp_id  label
# 344     17317442          0      0
# 230     16977523          0      0
# 167     16981092          0      1
# 282     16978241          0      0
# 217     16979381          0      0
#
# [5 rows x 25 columns]

# %%
#matcher
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='Naive Bayes')

result_recall = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
        k=5,
        target_attr='label', metric='recall', random_state=0)

result_recall['cv_stats']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
# 5   Naive Bayes
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x113e59150>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x113e59490>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x113e59210>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x113e59710>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x113e59110>
# 5          <py_entitymatching.matcher.nbmatcher.NBMatcher object at 0x113e59790>
#
#    Num folds    Fold 1  Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.888889    0.85  1.000000  0.714286  1.000000    0.890635
# 1          5  0.851852    0.95  0.916667  0.785714  1.000000    0.900847
# 2          5  0.777778    0.85  0.833333  0.785714  0.941176    0.837600
# 3          5  0.851852    0.95  0.833333  0.785714  1.000000    0.884180
# 4          5  0.851852    0.90  0.916667  0.785714  0.941176    0.879082
# 5          5  0.851852    0.85  0.916667  0.642857  0.941176    0.840510

# %%
result_precision = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
        k=5,
        target_attr='label', metric='precision', random_state=0)

result_precision['cv_stats']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
# 5   Naive Bayes
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x113e59150>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x113e59490>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x113e59210>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x113e59710>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x113e59110>
# 5          <py_entitymatching.matcher.nbmatcher.NBMatcher object at 0x113e59790>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  1.000000  1.000000  0.923077  0.769231  0.894737    0.917409
# 1          5  1.000000  0.950000  1.000000  0.916667  1.000000    0.973333
# 2          5  1.000000  0.944444  0.909091  1.000000  0.941176    0.958942
# 3          5  0.958333  1.000000  0.909091  0.846154  1.000000    0.942716
# 4          5  0.920000  1.000000  0.916667  0.846154  1.000000    0.936564
# 5          5  0.958333  0.944444  0.916667  1.000000  0.941176    0.952124

# %%
result_f1 = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
        k=5,
        target_attr='label', metric='f1', random_state=0)

result_f1['cv_stats']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
# 5   Naive Bayes
#
#                                                                          Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x113e59150>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x113e59490>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x113e59210>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x113e59710>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x113e59110>
# 5          <py_entitymatching.matcher.nbmatcher.NBMatcher object at 0x113e59790>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.941176  0.918919  0.960000  0.740741  0.944444    0.901056
# 1          5  0.920000  0.950000  0.956522  0.846154  1.000000    0.934535
# 2          5  0.875000  0.894737  0.869565  0.880000  0.941176    0.892096
# 3          5  0.901961  0.974359  0.869565  0.814815  1.000000    0.912140
# 4          5  0.884615  0.947368  0.916667  0.814815  0.969697    0.906632
# 5          5  0.901961  0.894737  0.916667  0.782609  0.941176    0.887430

# %%
L = em.extract_feature_vecs(J, 
                            feature_table=match_f, 
                            attrs_after='label',
                            show_progress=False)

# %%
L.head()
# Out:
#         _id     l_ID   r_ID  ID_ID_lev_dist  ID_ID_lev_sim  ID_ID_jar  \
# 58    45632  a137452  b2353               5       0.285714   0.561905
# 322  227071  a108802   b516               7       0.000000   0.464286
# 449  301326   a35119   b556               5       0.166667   0.472222
# 162   95297  a131477  b3564               6       0.142857   0.561905
# 348  239083    a6711  b1602               5       0.000000   0.466667
#
#      ID_ID_jwn  ID_ID_exm  ID_ID_jac_qgm_3_qgm_3  name_name_jac_qgm_3_qgm_3  \
# 58    0.561905          0                    0.0                   0.206897
# 322   0.464286          0                    0.0                   0.428571
# 449   0.472222          0                    0.0                   1.000000
# 162   0.561905          0                    0.0                   0.583333
# 348   0.466667          0                    0.0                   0.225806
#
#      ...    review_count_review_count_lev_sim  rating_rating_exm  \
# 58   ...                             0.333333                  0
# 322  ...                             0.000000                  0
# 449  ...                             0.333333                  0
# 162  ...                             0.000000                  0
# 348  ...                             0.000000                  0
#
#      rating_rating_anm  rating_rating_lev_dist  rating_rating_lev_sim  \
# 58            0.860000                     2.0               0.333333
# 322           0.909091                     1.0               0.666667
# 449           0.975610                     1.0               0.666667
# 162           0.952381                     1.0               0.666667
# 348           0.652174                     2.0               0.333333
#
#      zomato_id_zomato_id_exm  zomato_id_zomato_id_anm  \
# 58                         0                      0.0
# 322                        0                      0.0
# 449                        0                      0.0
# 162                        0                      0.0
# 348                        0                      0.0
#
#      zomato_id_zomato_id_lev_dist  zomato_id_zomato_id_lev_sim  label
# 58                              8                        0.000      0
# 322                             7                        0.125      0
# 449                             7                        0.125      1
# 162                             8                        0.000      1
# 348                             8                        0.000      0
#
# [5 rows x 54 columns]

# %%
rf.fit(table=H, 
      exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
       target_attr='label')

# %%
#NOW apply the best ML model to test set L


predictions = rf.predict(table=L, exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'], 
              append=True, target_attr='predicted', inplace=False)

# %%
eval_result = em.eval_matches(predictions, 'label', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 96.77% (90/93)
# Recall : 92.78% (90/97)
# F1 : 94.74%
# False positives : 3 (out of 93 positive predictions)
# False negatives : 7 (out of 207 negative predictions)

# %%
lg.fit(table=H, 
      exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
       target_attr='label')

# %%
predictions_lg = lg.predict(table=L, exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'], 
              append=True, target_attr='predicted', inplace=False)

# %%
eval_result2 = em.eval_matches(predictions_lg, 'label', 'predicted')
em.print_eval_summary(eval_result2)
# Out:
# Precision : 93.07% (94/101)
# Recall : 96.91% (94/97)
# F1 : 94.95%
# False positives : 7 (out of 101 positive predictions)
# False negatives : 3 (out of 199 negative predictions)

# %%
dt.fit(table=H, 
      exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
       target_attr='label')
predictions_dt = dt.predict(table=L, exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'], 
              append=True, target_attr='predicted', inplace=False)

eval_result_dt = em.eval_matches(predictions_dt, 'label', 'predicted')
em.print_eval_summary(eval_result_dt)
# Out:
# Precision : 93.55% (87/93)
# Recall : 89.69% (87/97)
# F1 : 91.58%
# False positives : 6 (out of 93 positive predictions)
# False negatives : 10 (out of 207 negative predictions)

# %%
svm.fit(table=H, 
      exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
       target_attr='label')
predictions_svm = svm.predict(table=L, exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'], 
              append=True, target_attr='predicted', inplace=False)

eval_result_svm = em.eval_matches(predictions_dt, 'label', 'predicted')
em.print_eval_summary(eval_result_svm)
# Out:
# Precision : 93.55% (87/93)
# Recall : 89.69% (87/97)
# F1 : 91.58%
# False positives : 6 (out of 93 positive predictions)
# False negatives : 10 (out of 207 negative predictions)

# %%
ln.fit(table=H, 
      exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
       target_attr='label')
predictions_ln = ln.predict(table=L, exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'], 
              append=True, target_attr='predicted', inplace=False)

eval_result_ln = em.eval_matches(predictions_ln, 'label', 'predicted')
em.print_eval_summary(eval_result_ln)
# Out:
# Precision : 97.78% (88/90)
# Recall : 90.72% (88/97)
# F1 : 94.12%
# False positives : 2 (out of 90 positive predictions)
# False negatives : 9 (out of 210 negative predictions)

# %%
nb.fit(table=H, 
      exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'],
       target_attr='label')
predictions_nb = nb.predict(table=L, exclude_attrs=['_id', 'l_ID', 'r_ID', 'label'], 
              append=True, target_attr='predicted', inplace=False)

eval_result_nb = em.eval_matches(predictions_nb, 'label', 'predicted')
em.print_eval_summary(eval_result_nb)
# Out:
# Precision : 96.74% (89/92)
# Recall : 91.75% (89/97)
# F1 : 94.18%
# False positives : 3 (out of 92 positive predictions)
# False negatives : 8 (out of 208 negative predictions)
